# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Number of published messages per second / Size of Messages

# %%
y = [11972.693535259807, 11490.576615114, 11114.924514517652, 12384.497173690708, 12056.34198619941, 10034.207643543241, 10630.452407149347, 10304.917700628532]
y_err = [4051.0122690291078, 2835.963722184428, 2384.7655963261727, 5296.092478948498, 4217.424834276756, 2239.5108822578454, 1823.3326145991139, 1516.006865760983]
x = [10, 20, 40, 80, 160, 320, 640, 1280]

# %%
plt.errorbar(x, y, yerr = y_err, capsize=5)
plt.xlabel("Size of message (bytes)")
plt.ylabel("Number of messages per second")
plt.savefig("plot1.png", dpi=300)

# %% [markdown]
# ### Number of published messages per second / Number of sent messages per second

# %%
y = [9.874443407807874, 19.54826038307288, 39.90881734572004, 79.3277704406311, 163.79967891903564, 313.3439341031171, 639.3829351240825, 1205.4583994789093]
y_err = [0.10434190778821169, 0.38941882428600766, 1.4569018328393784, 3.962222514377797, 15.439727401514103, 39.37626535506225, 81.73085649165283, 220.29990730995343]
x = [10, 20, 40, 80, 160, 320, 640, 1280]

# %%
plt.errorbar(x, y, yerr = y_err, capsize=5)
plt.xlabel("Number of published messages per second")
plt.ylabel("Number of sent messages per second")
plt.savefig("plot2.png", dpi=300)

# %% [markdown]
# ### Average Latency / Number of sent messages per second

# %%
y = [27.71967351770401, 29.285117265701295, 46.07921368151295, 35.35958448106592, 37.495485472433195, 19.008404773436485, 29.363732775747778, 33.22724737433717]
y_err = [5.765027333253878, 12.306007692032205, 14.835937458004013, 17.883095985300283, 19.537973108959182, 2.5098147933746513, 6.9977663154158005, 11.241135329076785]
x = [10, 20, 40, 80, 160, 320, 640, 1280]

# %%
plt.errorbar(x, y, yerr = y_err, capsize=5)
plt.xlabel("Average Latency")
plt.ylabel("Number of sent messages per second")
plt.savefig("plot3.png", dpi=300)
